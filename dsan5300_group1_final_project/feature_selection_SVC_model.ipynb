# %% [markdown]
# ### Import packages

# %%
import pandas as pd
from scipy.stats import spearmanr
from scipy.stats import chi2_contingency
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, fbeta_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFECV,SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold,cross_val_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import confusion_matrix, precision_score
from sklearn.metrics import confusion_matrix, recall_score
from imblearn.over_sampling import RandomOverSampler
from sklearn.svm import LinearSVC
from sklearn.metrics import roc_curve, roc_auc_score
from imblearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # BNPL1 - Full data

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# 1. LOAD DATA

# %%
# load data
data = pd.read_csv('data/data_merged.csv', index_col=False)
data = data.iloc[:,1:]
# Out:
# /var/folders/cr/df6gvtx90rz5bg2m0clb1gym0000gn/T/ipykernel_11632/2634253260.py:2: DtypeWarning: Columns (0: X12_a, 1: X12_b, 2: X12_c, 3: X12_d, 4: X12_e, 5: X12_f, 6: X12_g, 7: EF5C) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/data_merged.csv', index_col=False)

# %% [markdown]
# 2. DATA TRANSFORMATION

# %%
# [yes, no] --> [1,0]
# [female, male] --> [1,0]
cols1 = ['EF3_a','EF3_b','EF3_c','EF3_d','EF3_e','EF3_f','EF3_g','EF3_h','I41_c','I41_e','A1_a','A1_b','A1_c',
         'EF5C','EF1','SL6','ppgender','BNPL1']
map_cols1 = {
    "Yes": 1,
    "No": 0,
    "Female": 1,
    "Male": 0
}

for c in cols1:
  data[c] = data[c].map(map_cols1)

# %%
# OHE for multi-class categorical columns
cols2=['I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C']

cols2_dummies = {}
for c in cols2:
    cols2_dummies[c] = pd.get_dummies(data[c], prefix=c).astype(int)

data = pd.concat([data, pd.concat(cols2_dummies.values(), axis=1)], axis=1)

# %%
# multi-class to ordinal
cols3 = ['X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

map_cols3 = ({
    'Not a concern': 0,
    'Minor concern': 1,
    'Major concern': 2
})

for c in cols3:
  data[c] = data[c].map(map_cols3)

# %%
# rescale integer and continous variables
numeric_cols = ["ppage", "pphhsize", "ppkid017",'X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

scaler = StandardScaler()

data[numeric_cols] = scaler.fit_transform(data[numeric_cols])

# %%
# check nas
pd.set_option('display.max_rows', None)

data.drop(columns=['BNPL1', 'BNPL4_a', 'BNPL4_b', 'BNPL4_c', 'BNPL4_d', 'BNPL4_e', 'BNPL4_f', 'year',
                   # below columns are transformed to OHE columns. need to drop original ones
                       'I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C']).loc[-data['BNPL1'].isna()].isna().sum()
# Out:
# weight                                                                           0
# BNPL3                                                                        41725
# EF3_a                                                                            0
# EF3_b                                                                            0
# EF3_c                                                                            0
# EF3_d                                                                            0
# EF3_e                                                                            0
# EF3_f                                                                            0
# EF3_g                                                                            0
# EF3_h                                                                            0
# ppage                                                                            0
# ppgender                                                                         0
# pphhsize                                                                         0
# ppkid017                                                                         0
# SL6                                                                          40929
# EF1                                                                              0
# I41_c                                                                        18158
# I41_e                                                                        36413
# A1_a                                                                         30689
# A1_b                                                                         30689
# A1_c                                                                         30689
# X12_a                                                                        41111
# X12_b                                                                        41111
# X12_c                                                                        41111
# X12_d                                                                        41111
# X12_e                                                                        41111
# X12_f                                                                        41111
# X12_g                                                                        41111
# EF5C                                                                         23541
# I20_Less than your income                                                        0
# I20_More than your income                                                        0
# I20_The same as your income                                                      0
# ppfs0596_$1,000,000 or more                                                      0
# ppfs0596_$100,000 - $249,999                                                     0
# ppfs0596_$250,000 - $499,999                                                     0
# ppfs0596_$50,000 - $99,999                                                       0
# ppfs0596_$500,000 - $999,999                                                     0
# ppfs0596_Not sure                                                                0
# ppfs0596_Under $50,000                                                           0
# ppeducat_Bachelor's degree or higher                                             0
# ppeducat_High school graduate (high school diploma or the equivalent GED)        0
# ppeducat_No high school diploma or GED                                           0
# ppeducat_Some college or Associate's degree                                      0
# ppethm_2+ Races, Non-Hispanic                                                    0
# ppethm_Black, Non-Hispanic                                                       0
# ppethm_Hispanic                                                                  0
# ppethm_Other, Non-Hispanic                                                       0
# ppethm_White, Non-Hispanic                                                       0
# ppinc7_$10,000 to $24,999                                                        0
# ppinc7_$100,000 to $149,999                                                      0
# ppinc7_$150,000 or more                                                          0
# ppinc7_$25,000 to $49,999                                                        0
# ppinc7_$50,000 to $74,999                                                        0
# ppinc7_$75,000 to $99,999                                                        0
# ppinc7_Less than $10,000                                                         0
# ppemploy_Not working                                                             0
# ppemploy_Working full-time                                                       0
# ppemploy_Working part-time                                                       0
# ppmarit5_Divorced                                                                0
# ppmarit5_Never married                                                           0
# ppmarit5_Now married                                                             0
# ppmarit5_Separated                                                               0
# ppmarit5_Widowed                                                                 0
# ppagecat_18-24                                                                   0
# ppagecat_25-34                                                                   0
# ppagecat_35-44                                                                   0
# ppagecat_45-54                                                                   0
# ppagecat_55-64                                                                   0
# ppagecat_65-74                                                                   0
# ppagecat_75+                                                                     0
# ppfs1482_Don’t know                                                              0
# ppfs1482_Excellent                                                               0
# ppfs1482_Fair                                                                    0
# ppfs1482_Good                                                                    0
# ppfs1482_Poor                                                                    0
# ppfs1482_Very poor                                                               0
# B3_About the same                                                                0
# B3_Much better off                                                               0
# B3_Much worse off                                                                0
# B3_Somewhat better off                                                           0
# B3_Somewhat worse off                                                            0
# A6_Don’t know                                                                    0
# A6_Not confident                                                                 0
# A6_Somewhat confident                                                            0
# A6_Very confident                                                                0
# C4A_Most or all of the time                                                      0
# C4A_Never carried an unpaid balance (always pay in full)                         0
# C4A_Once                                                                         0
# C4A_Some of the time                                                             0
# L0C_1                                                                            0
# L0C_2                                                                            0
# L0C_3                                                                            0
# L0C_4                                                                            0
# L0C_5 or more                                                                    0
# dtype: int64

# %% [markdown]
# comment: leaving out columns SL6, I41_c, I41_e, A1_a, A1_b, A1_c, X12_a, X12_b, X12_c, X12_d, X12_e, X12_f, X12_g, EF5C from full data regression. include these columns for 2024 year regression.

# %%
# drop columns
data_cleaned = data.drop(columns=['BNPL3', 'BNPL4_a', 'BNPL4_b', 'BNPL4_c', 'BNPL4_d', 'BNPL4_e', 'BNPL4_f', 'year',
                       'I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C',
                       'SL6', 'I41_c', 'I41_e', 'A1_a', 'A1_b', 'A1_c', 'X12_a', 'X12_b', 'X12_c', 'X12_d', 'X12_e', 'X12_f', 'X12_g', 'EF5C'])
data_cleaned.loc[-data_cleaned['BNPL1'].isna()].isna().sum()

# independent variables
X = data_cleaned.drop(columns=['BNPL1','weight'])
# target variable
y = data_cleaned['BNPL1']

# weights
weights = data_cleaned['weight']

# %% [markdown]
# 3. Data resampling

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

print("Before:", Counter(y))

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print("After:", Counter(y_resampled))
# Out:
# Before: Counter({0: 41725, 1: 5511})
# After: Counter({0: 41725, 1: 41725})

# %% [markdown]
# ### Feature selection using SVC model

# %%
rfecv = RFECV(
    estimator=LinearSVC(max_iter=5000, penalty= 'l2', C=0.1),
    step=1,
    cv=StratifiedKFold(5, shuffle=True, random_state=42),
    scoring="f1"
)

rfecv.fit(X_resampled, y_resampled)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#       estimator=LinearSVC(C=0.1, max_iter=5000), scoring='f1')

# %%
selected_features_BNPL1 = X_resampled.columns[rfecv.support_]
print(selected_features_BNPL1)
print("Optimal number of features:", rfecv.n_features_)

# view columns selection
pd.DataFrame({
    "feature": X_resampled.columns,
    "selected": rfecv.support_
})
# Out:
# Index(['EF3_a', 'EF3_b', 'EF3_c', 'EF3_d', 'EF3_f', 'EF3_g', 'EF3_h', 'ppage',
#        'EF1', 'I20_Less than your income', 'I20_More than your income',
#        'I20_The same as your income', 'ppfs0596_$1,000,000 or more',
#        'ppfs0596_$100,000 - $249,999', 'ppfs0596_$250,000 - $499,999',
#        'ppfs0596_$50,000 - $99,999', 'ppfs0596_$500,000 - $999,999',
#        'ppfs0596_Not sure', 'ppfs0596_Under $50,000',
#        'ppeducat_Bachelor's degree or higher',
#        'ppeducat_High school graduate (high school diploma or the equivalent GED)',
#        'ppeducat_No high school diploma or GED',
#        'ppeducat_Some college or Associate's degree',
#        'ppethm_2+ Races, Non-Hispanic', 'ppethm_Black, Non-Hispanic',
#        'ppethm_Hispanic', 'ppethm_Other, Non-Hispanic',
#        'ppethm_White, Non-Hispanic', 'ppinc7_$10,000 to $24,999',
#        'ppinc7_$100,000 to $149,999', 'ppinc7_$150,000 or more',
#        'ppinc7_$25,000 to $49,999', 'ppinc7_$50,000 to $74,999',
#        'ppinc7_$75,000 to $99,999', 'ppinc7_Less than $10,000',
#        'ppemploy_Not working', 'ppemploy_Working full-time',
#        'ppemploy_Working part-time', 'ppmarit5_Divorced',
#        'ppmarit5_Never married', 'ppmarit5_Now married', 'ppmarit5_Separated',
#        'ppmarit5_Widowed', 'ppagecat_18-24', 'ppagecat_25-34',
#        'ppagecat_35-44', 'ppagecat_45-54', 'ppagecat_55-64', 'ppagecat_65-74',
#        'ppagecat_75+', 'ppfs1482_Don’t know', 'ppfs1482_Excellent',
#        'ppfs1482_Good', 'ppfs1482_Poor', 'ppfs1482_Very poor',
#        'B3_About the same', 'B3_Much better off', 'B3_Much worse off',
#        'B3_Somewhat better off', 'B3_Somewhat worse off', 'A6_Don’t know',
#        'A6_Not confident', 'A6_Somewhat confident', 'A6_Very confident',
#        'C4A_Most or all of the time',
#        'C4A_Never carried an unpaid balance (always pay in full)', 'C4A_Once',
#        'L0C_1', 'L0C_2', 'L0C_3', 'L0C_4'],
#       dtype='str')
# Optimal number of features: 71
#                                               feature  selected
# 0                                               EF3_a      True
# 1                                               EF3_b      True
# 2                                               EF3_c      True
# 3                                               EF3_d      True
# 4                                               EF3_e     False
# 5                                               EF3_f      True
# 6                                               EF3_g      True
# 7                                               EF3_h      True
# 8                                               ppage      True
# 9                                            ppgender     False
# 10                                           pphhsize     False
# 11                                           ppkid017     False
# 12                                                EF1      True
# 13                          I20_Less than your income      True
# 14                          I20_More than your income      True
# 15                        I20_The same as your income      True
# 16                        ppfs0596_$1,000,000 or more      True
# 17                       ppfs0596_$100,000 - $249,999      True
# 18                       ppfs0596_$250,000 - $499,999      True
# 19                         ppfs0596_$50,000 - $99,999      True
# 20                       ppfs0596_$500,000 - $999,999      True
# 21                                  ppfs0596_Not sure      True
# 22                             ppfs0596_Under $50,000      True
# 23               ppeducat_Bachelor's degree or higher      True
# 24  ppeducat_High school graduate (high school dip...      True
# 25             ppeducat_No high school diploma or GED      True
# 26        ppeducat_Some college or Associate's degree      True
# 27                      ppethm_2+ Races, Non-Hispanic      True
# 28                         ppethm_Black, Non-Hispanic      True
# 29                                    ppethm_Hispanic      True
# 30                         ppethm_Other, Non-Hispanic      True
# 31                         ppethm_White, Non-Hispanic      True
# 32                          ppinc7_$10,000 to $24,999      True
# 33                        ppinc7_$100,000 to $149,999      True
# 34                            ppinc7_$150,000 or more      True
# 35                          ppinc7_$25,000 to $49,999      True
# 36                          ppinc7_$50,000 to $74,999      True
# 37                          ppinc7_$75,000 to $99,999      True
# 38                           ppinc7_Less than $10,000      True
# 39                               ppemploy_Not working      True
# 40                         ppemploy_Working full-time      True
# 41                         ppemploy_Working part-time      True
# 42                                  ppmarit5_Divorced      True
# 43                             ppmarit5_Never married      True
# 44                               ppmarit5_Now married      True
# 45                                 ppmarit5_Separated      True
# 46                                   ppmarit5_Widowed      True
# 47                                     ppagecat_18-24      True
# 48                                     ppagecat_25-34      True
# 49                                     ppagecat_35-44      True
# 50                                     ppagecat_45-54      True
# 51                                     ppagecat_55-64      True
# 52                                     ppagecat_65-74      True
# 53                                       ppagecat_75+      True
# 54                                ppfs1482_Don’t know      True
# 55                                 ppfs1482_Excellent      True
# 56                                      ppfs1482_Fair     False
# 57                                      ppfs1482_Good      True
# 58                                      ppfs1482_Poor      True
# 59                                 ppfs1482_Very poor      True
# 60                                  B3_About the same      True
# 61                                 B3_Much better off      True
# 62                                  B3_Much worse off      True
# 63                             B3_Somewhat better off      True
# 64                              B3_Somewhat worse off      True
# 65                                      A6_Don’t know      True
# 66                                   A6_Not confident      True
# 67                              A6_Somewhat confident      True
# 68                                  A6_Very confident      True
# 69                        C4A_Most or all of the time      True
# 70  C4A_Never carried an unpaid balance (always pa...      True
# 71                                           C4A_Once      True
# 72                               C4A_Some of the time     False
# 73                                              L0C_1      True
# 74                                              L0C_2      True
# 75                                              L0C_3      True
# 76                                              L0C_4      True
# 77                                      L0C_5 or more     False

# %%
# a glimpse of accuracy
BNPL1_svc_model=LinearSVC(max_iter=5000)

X_selected = X_resampled[selected_features_BNPL1]

scores = cross_val_score(
    BNPL1_svc_model,
    X_selected,
    y_resampled,
    cv=5,
    scoring='f1'
)

print("CV F1 accuracy:", scores)
print("Mean F1 accuracy:", scores.mean())
# Out:
# CV accuracy: [0.49068548 0.97662211 0.97729769 0.9755919  0.95027167]
# Mean accuracy: 0.8740937698916772

# %% [markdown]
# comment: good accuracy using selected features fitting Linear SVC model.

# %% [markdown]
# ### SVC Model

# %% [markdown]
# Modeling

# %%
# ---------------------------
# 1. Prepare data
# ---------------------------
X_aug = X.copy()
X_aug = X_aug[selected_features_BNPL1]
X_aug["weight"] = weights

# ---------------------------
# 2. Train-test split
# ---------------------------
X_train_aug, X_test_aug, y_train, y_test = train_test_split(
    X_aug, y, test_size=0.2, random_state=42, stratify=y
)

# ---------------------------
# 3. Cross-validation
# ---------------------------
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

auc_scores = []
y_true_all = []
y_pred_all = []
weights_all = []
f1_scores = []

for train_idx, val_idx in skf.split(X_train_aug, y_train):

    X_tr = X_train_aug.iloc[train_idx].copy()
    X_val = X_train_aug.iloc[val_idx].copy()

    y_tr = y_train.iloc[train_idx]
    y_val = y_train.iloc[val_idx]

    # Resample ONLY training fold
    ros = RandomOverSampler(random_state=42)
    X_tr_res, y_tr_res = ros.fit_resample(X_tr, y_tr)

    # Extract weights
    w_tr_res = X_tr_res["weight"].values
    X_tr_res = X_tr_res.drop(columns=["weight"])

    w_val = X_val["weight"].values
    X_val = X_val.drop(columns=["weight"])

    # Train model
    model = LinearSVC(
        C=0.1,
        penalty='l1',
        dual=False,
        max_iter=5000
    )

    model.fit(X_tr_res, y_tr_res, sample_weight=w_tr_res)
    y_pred = model.predict(X_val)

    # ---------------------------
    # 4. Evaluation
    # ---------------------------

    # AUC
    y_scores = model.decision_function(X_val)
    auc = roc_auc_score(y_val, y_pred)
    auc_scores.append(auc)

    # F1
    f1 = f1_score(y_val, y_pred)
    f1_scores.append(f1)

    # Confusion matrix metrics
    y_true_all.extend(y_val)
    y_pred_all.extend(y_pred)
    weights_all.extend(w_val)

# %% [markdown]
# Evaluation results

# %%
# ---------------------------
# 5. Model results
# ---------------------------

print("CV AUC:", np.mean(auc_scores))
print("F1 Score:", np.mean(f1_scores))

cm = confusion_matrix(
    y_true_all,
    y_pred_all,
    sample_weight=weights_all,
    normalize='true'
)

print("Confusion Matrix:", cm)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=np.unique(y_train),
    yticklabels=np.unique(y_train)
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - BNPL1 SVC Model")
plt.show()
# Out:
# CV AUC: 0.6948224074703417
# F1 Score: 0.3447391976843478
# Confusion Matrix: [[0.65020608 0.34979392]
#  [0.26558427 0.73441573]]

# %% [markdown]
# Extract coefficients

# %%
ros = RandomOverSampler(random_state=42)
X_train_res, y_train_res = ros.fit_resample(X_train_aug, y_train)

w_train_res = X_train_res["weight"].values
X_train_res = X_train_res.drop(columns=["weight"])

final_model = LinearSVC(
    C=0.1,
    penalty='l1',
    dual=False,
    max_iter=5000
)

final_model.fit(X_train_res, y_train_res, sample_weight=w_train_res)
# Out:
# LinearSVC(C=0.1, dual=False, max_iter=5000, penalty='l1')

# %%
feature_names = X_train_res.columns

coefficients = final_model.coef_.flatten()

coef_df = pd.DataFrame({
    "feature": feature_names,
    "coefficient": coefficients
}).sort_values(by="coefficient", key=abs, ascending=False)

print(coef_df)
# Out:
#                                               feature  coefficient
# 50                                ppfs1482_Don’t know    -0.389930
# 65  C4A_Never carried an unpaid balance (always pa...    -0.270025
# 3                                               EF3_d     0.222494
# 51                                 ppfs1482_Excellent    -0.205060
# 64                        C4A_Most or all of the time     0.195097
# 4                                               EF3_f     0.186369
# 61                                   A6_Not confident     0.167785
# 24                         ppethm_Black, Non-Hispanic     0.157159
# 25                                    ppethm_Hispanic     0.147544
# 56                                 B3_Much better off     0.136130
# 43                                     ppagecat_18-24    -0.124779
# 34                           ppinc7_Less than $10,000    -0.124592
# 7                                               ppage    -0.119548
# 48                                     ppagecat_65-74     0.115770
# 1                                               EF3_b     0.113127
# 17                                  ppfs0596_Not sure    -0.112612
# 41                                 ppmarit5_Separated     0.099867
# 5                                               EF3_g     0.098096
# 15                         ppfs0596_$50,000 - $99,999    -0.097367
# 35                               ppemploy_Not working    -0.089749
# 62                              A6_Somewhat confident     0.088975
# 52                                      ppfs1482_Good    -0.088701
# 13                       ppfs0596_$100,000 - $249,999    -0.085665
# 10                          I20_More than your income     0.080571
# 27                         ppethm_White, Non-Hispanic    -0.076348
# 70                                              L0C_4     0.075696
# 58                             B3_Somewhat better off     0.074296
# 12                        ppfs0596_$1,000,000 or more    -0.071746
# 22        ppeducat_Some college or Associate's degree     0.063862
# 67                                              L0C_1     0.060317
# 40                               ppmarit5_Now married    -0.057136
# 28                          ppinc7_$10,000 to $24,999    -0.056276
# 55                                  B3_About the same    -0.056075
# 42                                   ppmarit5_Widowed     0.055197
# 16                       ppfs0596_$500,000 - $999,999    -0.054805
# 9                           I20_Less than your income    -0.052028
# 11                        I20_The same as your income     0.051062
# 2                                               EF3_c    -0.050586
# 47                                     ppagecat_55-64     0.048767
# 8                                                 EF1    -0.047376
# 14                       ppfs0596_$250,000 - $499,999    -0.046314
# 60                                      A6_Don’t know    -0.041065
# 46                                     ppagecat_45-54     0.040613
# 54                                 ppfs1482_Very poor    -0.038757
# 0                                               EF3_a     0.034664
# 36                         ppemploy_Working full-time     0.032708
# 45                                     ppagecat_35-44    -0.032004
# 33                          ppinc7_$75,000 to $99,999     0.027217
# 59                              B3_Somewhat worse off     0.026929
# 21             ppeducat_No high school diploma or GED    -0.025430
# 39                             ppmarit5_Never married    -0.023757
# 6                                               EF3_h     0.019885
# 32                          ppinc7_$50,000 to $74,999     0.019477
# 20  ppeducat_High school graduate (high school dip...     0.017201
# 38                                  ppmarit5_Divorced     0.014512
# 29                        ppinc7_$100,000 to $149,999     0.009309
# 31                          ppinc7_$25,000 to $49,999    -0.007998
# 66                                           C4A_Once     0.007515
# 53                                      ppfs1482_Poor    -0.007397
# 37                         ppemploy_Working part-time     0.003930
# 68                                              L0C_2    -0.003394
# 18                             ppfs0596_Under $50,000     0.001154
# 57                                  B3_Much worse off    -0.000129
# 63                                  A6_Very confident     0.000000
# 49                                       ppagecat_75+     0.000000
# 23                      ppethm_2+ Races, Non-Hispanic     0.000000
# 44                                     ppagecat_25-34     0.000000
# 19               ppeducat_Bachelor's degree or higher     0.000000
# 30                            ppinc7_$150,000 or more     0.000000
# 69                                              L0C_3     0.000000
# 26                         ppethm_Other, Non-Hispanic     0.000000

# %%
BNPL1_selected_features_high_coef = coef_df.iloc[(coef_df['coefficient']>=0.1) | (coef_df['coefficient']<=-0.1) ]

# %%
BNPL1_selected_features_high_coef
# Out:
#                                               feature  coefficient
# 50                                ppfs1482_Don’t know    -0.389930
# 65  C4A_Never carried an unpaid balance (always pa...    -0.270025
# 3                                               EF3_d     0.222494
# 51                                 ppfs1482_Excellent    -0.205060
# 64                        C4A_Most or all of the time     0.195097
# 4                                               EF3_f     0.186369
# 61                                   A6_Not confident     0.167785
# 24                         ppethm_Black, Non-Hispanic     0.157159
# 25                                    ppethm_Hispanic     0.147544
# 56                                 B3_Much better off     0.136130
# 43                                     ppagecat_18-24    -0.124779
# 34                           ppinc7_Less than $10,000    -0.124592
# 7                                               ppage    -0.119548
# 48                                     ppagecat_65-74     0.115770
# 1                                               EF3_b     0.113127
# 17                                  ppfs0596_Not sure    -0.112612

# %% [markdown]
# Retrain model with high coef selected features

# %%
# ---------------------------
# 1. Prepare data
# ---------------------------
X_aug = X.copy()
X_aug = X_aug[BNPL1_selected_features_high_coef['feature']]
X_aug["weight"] = weights

# ---------------------------
# 2. Train-test split
# ---------------------------
X_train_aug, X_test_aug, y_train, y_test = train_test_split(
    X_aug, y, test_size=0.2, random_state=42, stratify=y
)

# ---------------------------
# 3. Cross-validation
# ---------------------------
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

auc_scores = []
y_true_all = []
y_pred_all = []
weights_all = []
f1_scores = []

for train_idx, val_idx in skf.split(X_train_aug, y_train):

    X_tr = X_train_aug.iloc[train_idx].copy()
    X_val = X_train_aug.iloc[val_idx].copy()

    y_tr = y_train.iloc[train_idx]
    y_val = y_train.iloc[val_idx]

    # Resample ONLY training fold
    ros = RandomOverSampler(random_state=42)
    X_tr_res, y_tr_res = ros.fit_resample(X_tr, y_tr)

    # Extract weights
    w_tr_res = X_tr_res["weight"].values
    X_tr_res = X_tr_res.drop(columns=["weight"])

    w_val = X_val["weight"].values
    X_val = X_val.drop(columns=["weight"])

    # Train model
    model = LinearSVC(
        C=0.1,
        penalty='l1',
        dual=False,
        max_iter=5000
    )

    model.fit(X_tr_res, y_tr_res, sample_weight=w_tr_res)
    y_pred = model.predict(X_val)

    # ---------------------------
    # 4. Evaluation
    # ---------------------------

    # AUC
    y_scores = model.decision_function(X_val)
    auc = roc_auc_score(y_val, y_pred)
    auc_scores.append(auc)

    # F1
    f1 = f1_score(y_val, y_pred)
    f1_scores.append(f1)

    # Confusion matrix metrics
    y_true_all.extend(y_val)
    y_pred_all.extend(y_pred)
    weights_all.extend(w_val)

# %%
# ---------------------------
# 5. Model results
# ---------------------------

print("CV AUC:", np.mean(auc_scores))
print("F1 Score:", np.mean(f1_scores))

cm = confusion_matrix(
    y_true_all,
    y_pred_all,
    sample_weight=weights_all,
    normalize='true'
)

print("Confusion Matrix:", cm)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=np.unique(y_train),
    yticklabels=np.unique(y_train)
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - BNPL1 SVC Model")
plt.show()
# Out:
# CV AUC: 0.6887653205457687
# F1 Score: 0.3367050606958037
# Confusion Matrix: [[0.63168844 0.36831156]
#  [0.26194709 0.73805291]]

# %% [markdown]
# ## BNPL3 - full data

# %% [markdown]
# ### Data preprocessing

# %%
# load data
data = pd.read_csv('data/data_merged.csv', index_col=False)
data = data.iloc[:,1:]
# Out:
# /var/folders/cr/df6gvtx90rz5bg2m0clb1gym0000gn/T/ipykernel_11632/2634253260.py:2: DtypeWarning: Columns (0: X12_a, 1: X12_b, 2: X12_c, 3: X12_d, 4: X12_e, 5: X12_f, 6: X12_g, 7: EF5C) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/data_merged.csv', index_col=False)

# %%
# [yes, no] --> [1,0]
# [female, male] --> [1,0]
cols1 = ['EF3_a','EF3_b','EF3_c','EF3_d','EF3_e','EF3_f','EF3_g','EF3_h','I41_c','I41_e','A1_a','A1_b','A1_c',
         'EF5C','EF1','SL6','ppgender','BNPL3']
map_cols1 = {
    "Yes": 1,
    "No": 0,
    "Female": 1,
    "Male": 0
}

for c in cols1:
  data[c] = data[c].map(map_cols1)

# %%
# OHE for multi-class categorical columns
cols2=['I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C']

cols2_dummies = {}
for c in cols2:
    cols2_dummies[c] = pd.get_dummies(data[c], prefix=c).astype(int)

data = pd.concat([data, pd.concat(cols2_dummies.values(), axis=1)], axis=1)

# %%
# multi-class to ordinal
cols3 = ['X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

map_cols3 = ({
    'Not a concern': 0,
    'Minor concern': 1,
    'Major concern': 2
})

for c in cols3:
  data[c] = data[c].map(map_cols3)

# %%
# rescale integer and continous variables
numeric_cols = ["ppage", "pphhsize", "ppkid017",'X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

scaler = StandardScaler()

data[numeric_cols] = scaler.fit_transform(data[numeric_cols])

# %%
data = data.loc[-data['BNPL3'].isna()]

# %%
# check nas
pd.set_option('display.max_rows', None)

data.drop(columns=['BNPL1', 'BNPL4_a', 'BNPL4_b', 'BNPL4_c', 'BNPL4_d', 'BNPL4_e', 'BNPL4_f', 'year',
                   # below columns are transformed to OHE columns. need to drop original ones
                       'I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C']).loc[-data['BNPL3'].isna()].isna().sum()
# Out:
# weight                                                                          0
# BNPL3                                                                           0
# EF3_a                                                                           0
# EF3_b                                                                           0
# EF3_c                                                                           0
# EF3_d                                                                           0
# EF3_e                                                                           0
# EF3_f                                                                           0
# EF3_g                                                                           0
# EF3_h                                                                           0
# ppage                                                                           0
# ppgender                                                                        0
# pphhsize                                                                        0
# ppkid017                                                                        0
# SL6                                                                          3993
# EF1                                                                             0
# I41_c                                                                        1613
# I41_e                                                                        3774
# A1_a                                                                         2272
# A1_b                                                                         2272
# A1_c                                                                         2272
# X12_a                                                                        4704
# X12_b                                                                        4704
# X12_c                                                                        4704
# X12_d                                                                        4704
# X12_e                                                                        4704
# X12_f                                                                        4704
# X12_g                                                                        4704
# EF5C                                                                         2386
# I20_Less than your income                                                       0
# I20_More than your income                                                       0
# I20_The same as your income                                                     0
# ppfs0596_$1,000,000 or more                                                     0
# ppfs0596_$100,000 - $249,999                                                    0
# ppfs0596_$250,000 - $499,999                                                    0
# ppfs0596_$50,000 - $99,999                                                      0
# ppfs0596_$500,000 - $999,999                                                    0
# ppfs0596_Not sure                                                               0
# ppfs0596_Under $50,000                                                          0
# ppeducat_Bachelor's degree or higher                                            0
# ppeducat_High school graduate (high school diploma or the equivalent GED)       0
# ppeducat_No high school diploma or GED                                          0
# ppeducat_Some college or Associate's degree                                     0
# ppethm_2+ Races, Non-Hispanic                                                   0
# ppethm_Black, Non-Hispanic                                                      0
# ppethm_Hispanic                                                                 0
# ppethm_Other, Non-Hispanic                                                      0
# ppethm_White, Non-Hispanic                                                      0
# ppinc7_$10,000 to $24,999                                                       0
# ppinc7_$100,000 to $149,999                                                     0
# ppinc7_$150,000 or more                                                         0
# ppinc7_$25,000 to $49,999                                                       0
# ppinc7_$50,000 to $74,999                                                       0
# ppinc7_$75,000 to $99,999                                                       0
# ppinc7_Less than $10,000                                                        0
# ppemploy_Not working                                                            0
# ppemploy_Working full-time                                                      0
# ppemploy_Working part-time                                                      0
# ppmarit5_Divorced                                                               0
# ppmarit5_Never married                                                          0
# ppmarit5_Now married                                                            0
# ppmarit5_Separated                                                              0
# ppmarit5_Widowed                                                                0
# ppagecat_18-24                                                                  0
# ppagecat_25-34                                                                  0
# ppagecat_35-44                                                                  0
# ppagecat_45-54                                                                  0
# ppagecat_55-64                                                                  0
# ppagecat_65-74                                                                  0
# ppagecat_75+                                                                    0
# ppfs1482_Don’t know                                                             0
# ppfs1482_Excellent                                                              0
# ppfs1482_Fair                                                                   0
# ppfs1482_Good                                                                   0
# ppfs1482_Poor                                                                   0
# ppfs1482_Very poor                                                              0
# B3_About the same                                                               0
# B3_Much better off                                                              0
# B3_Much worse off                                                               0
# B3_Somewhat better off                                                          0
# B3_Somewhat worse off                                                           0
# A6_Don’t know                                                                   0
# A6_Not confident                                                                0
# A6_Somewhat confident                                                           0
# A6_Very confident                                                               0
# C4A_Most or all of the time                                                     0
# C4A_Never carried an unpaid balance (always pay in full)                        0
# C4A_Once                                                                        0
# C4A_Some of the time                                                            0
# L0C_1                                                                           0
# L0C_2                                                                           0
# L0C_3                                                                           0
# L0C_4                                                                           0
# L0C_5 or more                                                                   0
# dtype: int64

# %% [markdown]
# comment: leaving out columns SL6, I41_c, I41_e, A1_a, A1_b, A1_c, X12_a, X12_b, X12_c, X12_d, X12_e, X12_f, X12_g, EF5C from full data regression. include these columns for 2024 year regression.

# %%
# drop columns
data_cleaned = data.drop(columns=['BNPL1', 'BNPL4_a', 'BNPL4_b', 'BNPL4_c', 'BNPL4_d', 'BNPL4_e', 'BNPL4_f', 'year',
                       'I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C',
                       'SL6', 'I41_c', 'I41_e', 'A1_a', 'A1_b', 'A1_c', 'X12_a', 'X12_b', 'X12_c', 'X12_d', 'X12_e', 'X12_f', 'X12_g', 'EF5C'])


# independent variables
X = data_cleaned.drop(columns=['BNPL3','weight'])
# target variable
y = data_cleaned['BNPL3']

# weights
weights = data_cleaned['weight']

# %% [markdown]
# ### Feature selection

# %%
from imblearn.pipeline import Pipeline

BNPL3_svc_model = LinearSVC(max_iter=2000)

rfecv = RFECV(
    estimator=BNPL3_svc_model,
    step=1,
    cv=StratifiedKFold(5, shuffle=True, random_state=42),
    scoring="f1"
)

# pipeline: resampling happens BEFORE RFECV in each fold
pipeline = Pipeline(steps=[
    ("resample", RandomOverSampler(random_state=42)),
    ("feature_selection", rfecv)
])

# Fit pipeline
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('resample', RandomOverSampler(random_state=42)),
#                 ('feature_selection',
#                  RFECV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                        estimator=LinearSVC(max_iter=2000), scoring='f1'))])

# %%
# get selected features
rfecv = pipeline.named_steps["feature_selection"]
mask = rfecv.support_
selected_features_BNPL3 = X.columns[mask]
print(selected_features_BNPL3)
# Out:
# Index(['EF3_c', 'EF3_d', 'EF3_e', 'EF3_f', 'EF3_h', 'ppkid017',
#        'I20_Less than your income', 'ppfs0596_$1,000,000 or more',
#        'ppfs0596_$250,000 - $499,999', 'ppfs0596_$500,000 - $999,999',
#        'ppfs0596_Under $50,000', 'ppeducat_No high school diploma or GED',
#        'ppethm_2+ Races, Non-Hispanic', 'ppethm_Other, Non-Hispanic',
#        'ppethm_White, Non-Hispanic', 'ppinc7_$10,000 to $24,999',
#        'ppinc7_$100,000 to $149,999', 'ppinc7_$150,000 or more',
#        'ppinc7_$75,000 to $99,999', 'ppinc7_Less than $10,000',
#        'ppmarit5_Divorced', 'ppmarit5_Never married', 'ppagecat_18-24',
#        'ppagecat_45-54', 'ppagecat_65-74', 'ppagecat_75+',
#        'ppfs1482_Excellent', 'ppfs1482_Fair', 'ppfs1482_Poor',
#        'ppfs1482_Very poor', 'B3_Much worse off', 'A6_Not confident',
#        'A6_Very confident', 'C4A_Most or all of the time',
#        'C4A_Never carried an unpaid balance (always pay in full)', 'C4A_Once',
#        'C4A_Some of the time', 'L0C_1', 'L0C_2', 'L0C_3', 'L0C_4',
#        'L0C_5 or more'],
#       dtype='str')

# %% [markdown]
# ### SVC Model

# %% [markdown]
# Modeling

# %%
# ---------------------------
# 1. Prepare data
# ---------------------------
X_aug = X.copy()
X_aug = X_aug[selected_features_BNPL3]
X_aug["weight"] = weights

# ---------------------------
# 2. Train-test split
# ---------------------------
X_train_aug, X_test_aug, y_train, y_test = train_test_split(
    X_aug, y, test_size=0.2, random_state=42, stratify=y
)

# ---------------------------
# 3. Cross-validation
# ---------------------------
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

auc_scores = []
y_true_all = []
y_pred_all = []
weights_all = []
f1_scores = []

for train_idx, val_idx in skf.split(X_train_aug, y_train):

    X_tr = X_train_aug.iloc[train_idx].copy()
    X_val = X_train_aug.iloc[val_idx].copy()

    y_tr = y_train.iloc[train_idx]
    y_val = y_train.iloc[val_idx]

    # Resample ONLY training fold
    ros = RandomOverSampler(random_state=42)
    X_tr_res, y_tr_res = ros.fit_resample(X_tr, y_tr)

    # Extract weights
    w_tr_res = X_tr_res["weight"].values
    X_tr_res = X_tr_res.drop(columns=["weight"])

    w_val = X_val["weight"].values
    X_val = X_val.drop(columns=["weight"])

    # Train model
    model = LinearSVC(
        C=0.1,
        penalty='l1',
        dual=False,
        max_iter=5000
    )

    model.fit(X_tr_res, y_tr_res, sample_weight=w_tr_res)
    y_pred = model.predict(X_val)

    # ---------------------------
    # 4. Evaluation
    # ---------------------------

    # AUC
    y_scores = model.decision_function(X_val)
    auc = roc_auc_score(y_val, y_pred)
    auc_scores.append(auc)

    # F1
    f1 = f1_score(y_val, y_pred)
    f1_scores.append(f1)

    # Confusion matrix metrics
    y_true_all.extend(y_val)
    y_pred_all.extend(y_pred)
    weights_all.extend(w_val)

# %% [markdown]
# Evaluation results

# %%
# ---------------------------
# 5. Model results
# ---------------------------

print("CV AUC:", np.mean(auc_scores))
print("F1 Score:", np.mean(f1_scores))

cm = confusion_matrix(
    y_true_all,
    y_pred_all,
    sample_weight=weights_all,
    normalize='true'
)

print("Confusion Matrix:", cm)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=np.unique(y_train),
    yticklabels=np.unique(y_train)
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - BNPL3 SVC Model")
plt.show()
# Out:
# CV AUC: 0.7294146480045225
# F1 Score: 0.48647578339066805
# Confusion Matrix: [[0.70346272 0.29653728]
#  [0.25238914 0.74761086]]

# %% [markdown]
# ## BNPL1 - 2024 data

# %% [markdown]
# ### Data pre-processing

# %%
# load data
data = pd.read_csv('data/data_merged.csv', index_col=False)
data = data.iloc[:,1:]
data_2024 = data.loc[data['year']==2024]
# Out:
# /var/folders/cr/df6gvtx90rz5bg2m0clb1gym0000gn/T/ipykernel_11632/2448053278.py:2: DtypeWarning: Columns (0: X12_a, 1: X12_b, 2: X12_c, 3: X12_d, 4: X12_e, 5: X12_f, 6: X12_g, 7: EF5C) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/data_merged.csv', index_col=False)

# %%
# [yes, no] --> [1,0]
# [female, male] --> [1,0]
cols1 = ['EF3_a','EF3_b','EF3_c','EF3_d','EF3_e','EF3_f','EF3_g','EF3_h','I41_c','I41_e','A1_a','A1_b','A1_c',
         'EF5C','EF1','SL6','ppgender','BNPL1']
map_cols1 = {
    "Yes": 1,
    "No": 0,
    "Female": 1,
    "Male": 0
}

for c in cols1:
  data_2024[c] = data_2024[c].map(map_cols1)

# %%
# OHE for multi-class categorical columns
cols2=['I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C']

cols2_dummies = {}
for c in cols2:
    cols2_dummies[c] = pd.get_dummies(data_2024[c], prefix=c).astype(int)

data_2024 = pd.concat([data_2024, pd.concat(cols2_dummies.values(), axis=1)], axis=1)

# %%
# multi-class to ordinal
cols3 = ['X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

map_cols3 = ({
    'Not a concern': 0,
    'Minor concern': 1,
    'Major concern': 2
})

for c in cols3:
  data_2024[c] = data_2024[c].map(map_cols3)

# %%
# rescale integer and continous variables
numeric_cols = ["ppage", "pphhsize", "ppkid017",'X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

scaler = StandardScaler()

data_2024[numeric_cols] = scaler.fit_transform(data_2024[numeric_cols])

# %%
data_2024 = data_2024.loc[-data_2024['BNPL1'].isna()]

# %%
# drop columns
data2024_cleaned = data_2024.drop(columns=['BNPL3', 'BNPL4_a', 'BNPL4_b', 'BNPL4_c', 'BNPL4_d', 'BNPL4_e', 'BNPL4_f', 'year',
                      'I41_c','I41_e', 'SL6', 'I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C'])

# %%
data2024_cleaned.isna().sum()
# Out:
# weight                                                                          0
# BNPL1                                                                           0
# EF3_a                                                                           0
# EF3_b                                                                           0
# EF3_c                                                                           0
# EF3_d                                                                           0
# EF3_e                                                                           0
# EF3_f                                                                           0
# EF3_g                                                                           0
# EF3_h                                                                           0
# ppage                                                                           0
# ppgender                                                                        0
# pphhsize                                                                        0
# ppkid017                                                                        0
# EF1                                                                             0
# A1_a                                                                         8184
# A1_b                                                                         8184
# A1_c                                                                         8184
# X12_a                                                                        6170
# X12_b                                                                        6170
# X12_c                                                                        6170
# X12_d                                                                        6170
# X12_e                                                                        6170
# X12_f                                                                        6170
# X12_g                                                                        6170
# EF5C                                                                            0
# I20_Less than your income                                                       0
# I20_More than your income                                                       0
# I20_The same as your income                                                     0
# ppfs0596_$1,000,000 or more                                                     0
# ppfs0596_$100,000 - $249,999                                                    0
# ppfs0596_$250,000 - $499,999                                                    0
# ppfs0596_$50,000 - $99,999                                                      0
# ppfs0596_$500,000 - $999,999                                                    0
# ppfs0596_Not sure                                                               0
# ppfs0596_Under $50,000                                                          0
# ppeducat_Bachelor's degree or higher                                            0
# ppeducat_High school graduate (high school diploma or the equivalent GED)       0
# ppeducat_No high school diploma or GED                                          0
# ppeducat_Some college or Associate's degree                                     0
# ppethm_2+ Races, Non-Hispanic                                                   0
# ppethm_Black, Non-Hispanic                                                      0
# ppethm_Hispanic                                                                 0
# ppethm_Other, Non-Hispanic                                                      0
# ppethm_White, Non-Hispanic                                                      0
# ppinc7_$10,000 to $24,999                                                       0
# ppinc7_$100,000 to $149,999                                                     0
# ppinc7_$150,000 or more                                                         0
# ppinc7_$25,000 to $49,999                                                       0
# ppinc7_$50,000 to $74,999                                                       0
# ppinc7_$75,000 to $99,999                                                       0
# ppinc7_Less than $10,000                                                        0
# ppemploy_Not working                                                            0
# ppemploy_Working full-time                                                      0
# ppemploy_Working part-time                                                      0
# ppmarit5_Divorced                                                               0
# ppmarit5_Never married                                                          0
# ppmarit5_Now married                                                            0
# ppmarit5_Separated                                                              0
# ppmarit5_Widowed                                                                0
# ppagecat_18-24                                                                  0
# ppagecat_25-34                                                                  0
# ppagecat_35-44                                                                  0
# ppagecat_45-54                                                                  0
# ppagecat_55-64                                                                  0
# ppagecat_65-74                                                                  0
# ppagecat_75+                                                                    0
# ppfs1482_Don’t know                                                             0
# ppfs1482_Excellent                                                              0
# ppfs1482_Fair                                                                   0
# ppfs1482_Good                                                                   0
# ppfs1482_Poor                                                                   0
# ppfs1482_Very poor                                                              0
# B3_About the same                                                               0
# B3_Much better off                                                              0
# B3_Much worse off                                                               0
# B3_Somewhat better off                                                          0
# B3_Somewhat worse off                                                           0
# A6_Don’t know                                                                   0
# A6_Not confident                                                                0
# A6_Somewhat confident                                                           0
# A6_Very confident                                                               0
# C4A_Most or all of the time                                                     0
# C4A_Never carried an unpaid balance (always pay in full)                        0
# C4A_Once                                                                        0
# C4A_Some of the time                                                            0
# L0C_1                                                                           0
# L0C_2                                                                           0
# L0C_3                                                                           0
# L0C_4                                                                           0
# L0C_5 or more                                                                   0
# dtype: int64

# %%
data2024_cleaned = data2024_cleaned.dropna()

# %% [markdown]
# ### Feature selection

# %%
# independent variables
X = data2024_cleaned.drop(columns=['BNPL1','weight'])
# target variable
y = data2024_cleaned['BNPL1']

# weights
weights = data2024_cleaned['weight']

# %%
from imblearn.pipeline import Pipeline

BNPL1_2024_svc_model = LinearSVC(max_iter=2000)

rfecv = RFECV(
    estimator=BNPL1_2024_svc_model,
    step=1,
    cv=StratifiedKFold(5, shuffle=True, random_state=42),
    scoring="f1"
)

# pipeline: resampling happens BEFORE RFECV in each fold
pipeline = Pipeline(steps=[
    ("resample", RandomOverSampler(random_state=42)),
    ("feature_selection", rfecv)
])

# Fit pipeline
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('resample', RandomOverSampler(random_state=42)),
#                 ('feature_selection',
#                  RFECV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                        estimator=LinearSVC(max_iter=2000), scoring='f1'))])

# %%
# get selected features
rfecv = pipeline.named_steps["feature_selection"]
mask = rfecv.support_
selected_features_BNPL1_2024 = X.columns[mask]
print(selected_features_BNPL1_2024)
# Out:
# Index(['EF3_a', 'EF3_c', 'EF3_d', 'EF3_e', 'EF3_f', 'EF3_g', 'EF3_h', 'ppage',
#        'ppgender', 'ppkid017', 'EF1', 'A1_a', 'A1_b', 'A1_c', 'X12_b', 'X12_c',
#        'X12_d', 'X12_g', 'I20_Less than your income',
#        'ppfs0596_$1,000,000 or more', 'ppfs0596_$100,000 - $249,999',
#        'ppfs0596_$250,000 - $499,999', 'ppfs0596_$50,000 - $99,999',
#        'ppfs0596_$500,000 - $999,999', 'ppfs0596_Not sure',
#        'ppfs0596_Under $50,000', 'ppeducat_Bachelor's degree or higher',
#        'ppeducat_High school graduate (high school diploma or the equivalent GED)',
#        'ppeducat_No high school diploma or GED',
#        'ppeducat_Some college or Associate's degree',
#        'ppethm_2+ Races, Non-Hispanic', 'ppethm_Black, Non-Hispanic',
#        'ppethm_Hispanic', 'ppethm_Other, Non-Hispanic',
#        'ppethm_White, Non-Hispanic', 'ppinc7_$10,000 to $24,999',
#        'ppinc7_$150,000 or more', 'ppinc7_$25,000 to $49,999',
#        'ppinc7_$75,000 to $99,999', 'ppinc7_Less than $10,000',
#        'ppmarit5_Now married', 'ppmarit5_Separated', 'ppagecat_18-24',
#        'ppagecat_25-34', 'ppagecat_35-44', 'ppagecat_55-64', 'ppagecat_65-74',
#        'ppagecat_75+', 'ppfs1482_Don’t know', 'ppfs1482_Fair', 'ppfs1482_Good',
#        'ppfs1482_Poor', 'ppfs1482_Very poor', 'B3_About the same',
#        'B3_Much better off', 'B3_Much worse off', 'B3_Somewhat better off',
#        'B3_Somewhat worse off', 'A6_Don’t know', 'A6_Very confident',
#        'C4A_Most or all of the time',
#        'C4A_Never carried an unpaid balance (always pay in full)', 'C4A_Once',
#        'C4A_Some of the time', 'L0C_1', 'L0C_2', 'L0C_3', 'L0C_4',
#        'L0C_5 or more'],
#       dtype='str')

# %% [markdown]
# ### SVC Model

# %% [markdown]
# Modeling

# %%
# ---------------------------
# 1. Prepare data
# ---------------------------
X_aug = X.copy()
X_aug = X_aug[selected_features_BNPL1_2024]
X_aug["weight"] = weights

# ---------------------------
# 2. Train-test split
# ---------------------------
X_train_aug, X_test_aug, y_train, y_test = train_test_split(
    X_aug, y, test_size=0.2, random_state=42, stratify=y
)

# ---------------------------
# 3. Cross-validation
# ---------------------------
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

auc_scores = []
y_true_all = []
y_pred_all = []
weights_all = []
f1_scores = []

for train_idx, val_idx in skf.split(X_train_aug, y_train):

    X_tr = X_train_aug.iloc[train_idx].copy()
    X_val = X_train_aug.iloc[val_idx].copy()

    y_tr = y_train.iloc[train_idx]
    y_val = y_train.iloc[val_idx]

    # Resample ONLY training fold
    ros = RandomOverSampler(random_state=42)
    X_tr_res, y_tr_res = ros.fit_resample(X_tr, y_tr)

    # Extract weights
    w_tr_res = X_tr_res["weight"].values
    X_tr_res = X_tr_res.drop(columns=["weight"])

    w_val = X_val["weight"].values
    X_val = X_val.drop(columns=["weight"])

    # Train model
    model = LinearSVC(
        C=0.1,
        penalty='l1',
        dual=False,
        max_iter=5000
    )

    model.fit(X_tr_res, y_tr_res, sample_weight=w_tr_res)
    y_pred = model.predict(X_val)

    # ---------------------------
    # 4. Evaluation
    # ---------------------------

    # AUC
    y_scores = model.decision_function(X_val)
    auc = roc_auc_score(y_val, y_pred)
    auc_scores.append(auc)

    # F1
    f1 = f1_score(y_val, y_pred)
    f1_scores.append(f1)

    # Confusion matrix metrics
    y_true_all.extend(y_val)
    y_pred_all.extend(y_pred)
    weights_all.extend(w_val)

# %%
# ---------------------------
# 5. Model results
# ---------------------------

print("CV AUC:", np.mean(auc_scores))
print("F1 Score:", np.mean(f1_scores))

cm = confusion_matrix(
    y_true_all,
    y_pred_all,
    sample_weight=weights_all,
    normalize='true'
)

print("Confusion Matrix:", cm)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=np.unique(y_train),
    yticklabels=np.unique(y_train)
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - BNPL1 2024 SVC Model")
plt.show()
# Out:
# CV AUC: 0.6685393563818222
# F1 Score: 0.47314703107477063
# Confusion Matrix: [[0.64623393 0.35376607]
#  [0.32955521 0.67044479]]

# %% [markdown]
# ## BNPL3 - 2024 data

# %% [markdown]
# ### Data pre-processing

# %%
# load data
data = pd.read_csv('data/data_merged.csv', index_col=False)
data = data.iloc[:,1:]
data_2024 = data.loc[data['year']==2024]
# Out:
# /var/folders/cr/df6gvtx90rz5bg2m0clb1gym0000gn/T/ipykernel_11632/2448053278.py:2: DtypeWarning: Columns (0: X12_a, 1: X12_b, 2: X12_c, 3: X12_d, 4: X12_e, 5: X12_f, 6: X12_g, 7: EF5C) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/data_merged.csv', index_col=False)

# %%
# [yes, no] --> [1,0]
# [female, male] --> [1,0]
cols1 = ['EF3_a','EF3_b','EF3_c','EF3_d','EF3_e','EF3_f','EF3_g','EF3_h','I41_c','I41_e','A1_a','A1_b','A1_c',
         'EF5C','EF1','SL6','ppgender','BNPL3']
map_cols1 = {
    "Yes": 1,
    "No": 0,
    "Female": 1,
    "Male": 0
}

for c in cols1:
  data_2024[c] = data_2024[c].map(map_cols1)

# %%
# OHE for multi-class categorical columns
cols2=['I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C']

cols2_dummies = {}
for c in cols2:
    cols2_dummies[c] = pd.get_dummies(data_2024[c], prefix=c).astype(int)

data_2024 = pd.concat([data_2024, pd.concat(cols2_dummies.values(), axis=1)], axis=1)

# %%
# multi-class to ordinal
cols3 = ['X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

map_cols3 = ({
    'Not a concern': 0,
    'Minor concern': 1,
    'Major concern': 2
})

for c in cols3:
  data_2024[c] = data_2024[c].map(map_cols3)

# %%
# rescale integer and continous variables
numeric_cols = ["ppage", "pphhsize", "ppkid017",'X12_a','X12_b','X12_c','X12_d','X12_e','X12_f','X12_g']

scaler = StandardScaler()

data_2024[numeric_cols] = scaler.fit_transform(data_2024[numeric_cols])

# %%
data_2024 = data_2024.loc[-data_2024['BNPL3'].isna()]

# %%
data_2024.isna().sum()
# Out:
# weight                                                                          0
# BNPL1                                                                           0
# BNPL3                                                                           0
# BNPL4_a                                                                         0
# BNPL4_b                                                                         0
# BNPL4_c                                                                         0
# BNPL4_d                                                                         0
# BNPL4_e                                                                         0
# BNPL4_f                                                                         0
# EF3_a                                                                           0
# EF3_b                                                                           0
# EF3_c                                                                           0
# EF3_d                                                                           0
# EF3_e                                                                           0
# EF3_f                                                                           0
# EF3_g                                                                           0
# EF3_h                                                                           0
# I20                                                                             0
# ppfs0596                                                                     1430
# ppeducat                                                                        0
# ppage                                                                           0
# ppagecat                                                                        0
# ppethm                                                                          0
# ppgender                                                                        0
# ppinc7                                                                          0
# ppemploy                                                                        0
# ppmarit5                                                                        0
# pphhsize                                                                        0
# ppkid017                                                                        0
# ppfs1482                                                                      462
# SL6                                                                          1249
# B3                                                                              0
# A6                                                                              0
# C4A                                                                           286
# EF1                                                                             0
# L0C                                                                          1165
# I41_c                                                                           0
# I41_e                                                                        1165
# A1_a                                                                          735
# A1_b                                                                          735
# A1_c                                                                          735
# X12_a                                                                         863
# X12_b                                                                         863
# X12_c                                                                         863
# X12_d                                                                         863
# X12_e                                                                         863
# X12_f                                                                         863
# X12_g                                                                         863
# EF5C                                                                            0
# year                                                                            0
# I20_Less than your income                                                       0
# I20_More than your income                                                       0
# I20_The same as your income                                                     0
# ppfs0596_$1,000,000 or more                                                     0
# ppfs0596_$100,000 - $249,999                                                    0
# ppfs0596_$250,000 - $499,999                                                    0
# ppfs0596_$50,000 - $99,999                                                      0
# ppfs0596_$500,000 - $999,999                                                    0
# ppfs0596_Not sure                                                               0
# ppfs0596_Under $50,000                                                          0
# ppeducat_Bachelor's degree or higher                                            0
# ppeducat_High school graduate (high school diploma or the equivalent GED)       0
# ppeducat_No high school diploma or GED                                          0
# ppeducat_Some college or Associate's degree                                     0
# ppethm_2+ Races, Non-Hispanic                                                   0
# ppethm_Black, Non-Hispanic                                                      0
# ppethm_Hispanic                                                                 0
# ppethm_Other, Non-Hispanic                                                      0
# ppethm_White, Non-Hispanic                                                      0
# ppinc7_$10,000 to $24,999                                                       0
# ppinc7_$100,000 to $149,999                                                     0
# ppinc7_$150,000 or more                                                         0
# ppinc7_$25,000 to $49,999                                                       0
# ppinc7_$50,000 to $74,999                                                       0
# ppinc7_$75,000 to $99,999                                                       0
# ppinc7_Less than $10,000                                                        0
# ppemploy_Not working                                                            0
# ppemploy_Working full-time                                                      0
# ppemploy_Working part-time                                                      0
# ppmarit5_Divorced                                                               0
# ppmarit5_Never married                                                          0
# ppmarit5_Now married                                                            0
# ppmarit5_Separated                                                              0
# ppmarit5_Widowed                                                                0
# ppagecat_18-24                                                                  0
# ppagecat_25-34                                                                  0
# ppagecat_35-44                                                                  0
# ppagecat_45-54                                                                  0
# ppagecat_55-64                                                                  0
# ppagecat_65-74                                                                  0
# ppagecat_75+                                                                    0
# ppfs1482_Don’t know                                                             0
# ppfs1482_Excellent                                                              0
# ppfs1482_Fair                                                                   0
# ppfs1482_Good                                                                   0
# ppfs1482_Poor                                                                   0
# ppfs1482_Very poor                                                              0
# B3_About the same                                                               0
# B3_Much better off                                                              0
# B3_Much worse off                                                               0
# B3_Somewhat better off                                                          0
# B3_Somewhat worse off                                                           0
# A6_Don’t know                                                                   0
# A6_Not confident                                                                0
# A6_Somewhat confident                                                           0
# A6_Very confident                                                               0
# C4A_Most or all of the time                                                     0
# C4A_Never carried an unpaid balance (always pay in full)                        0
# C4A_Once                                                                        0
# C4A_Some of the time                                                            0
# L0C_1                                                                           0
# L0C_2                                                                           0
# L0C_3                                                                           0
# L0C_4                                                                           0
# L0C_5 or more                                                                   0
# dtype: int64

# %%
# drop columns
data2024_cleaned = data_2024.drop(columns=['BNPL1', 'BNPL4_a', 'BNPL4_b', 'BNPL4_c', 'BNPL4_d', 'BNPL4_e', 'BNPL4_f', 'year',
                      'I41_e', 'SL6', 'I20','ppfs0596','ppeducat','ppethm','ppinc7','ppemploy','ppmarit5','ppagecat','ppfs1482','B3','A6','C4A','L0C'])

# %%
data2024_cleaned.isna().sum()
# Out:
# weight                                                                         0
# BNPL3                                                                          0
# EF3_a                                                                          0
# EF3_b                                                                          0
# EF3_c                                                                          0
# EF3_d                                                                          0
# EF3_e                                                                          0
# EF3_f                                                                          0
# EF3_g                                                                          0
# EF3_h                                                                          0
# ppage                                                                          0
# ppgender                                                                       0
# pphhsize                                                                       0
# ppkid017                                                                       0
# EF1                                                                            0
# I41_c                                                                          0
# A1_a                                                                         735
# A1_b                                                                         735
# A1_c                                                                         735
# X12_a                                                                        863
# X12_b                                                                        863
# X12_c                                                                        863
# X12_d                                                                        863
# X12_e                                                                        863
# X12_f                                                                        863
# X12_g                                                                        863
# EF5C                                                                           0
# I20_Less than your income                                                      0
# I20_More than your income                                                      0
# I20_The same as your income                                                    0
# ppfs0596_$1,000,000 or more                                                    0
# ppfs0596_$100,000 - $249,999                                                   0
# ppfs0596_$250,000 - $499,999                                                   0
# ppfs0596_$50,000 - $99,999                                                     0
# ppfs0596_$500,000 - $999,999                                                   0
# ppfs0596_Not sure                                                              0
# ppfs0596_Under $50,000                                                         0
# ppeducat_Bachelor's degree or higher                                           0
# ppeducat_High school graduate (high school diploma or the equivalent GED)      0
# ppeducat_No high school diploma or GED                                         0
# ppeducat_Some college or Associate's degree                                    0
# ppethm_2+ Races, Non-Hispanic                                                  0
# ppethm_Black, Non-Hispanic                                                     0
# ppethm_Hispanic                                                                0
# ppethm_Other, Non-Hispanic                                                     0
# ppethm_White, Non-Hispanic                                                     0
# ppinc7_$10,000 to $24,999                                                      0
# ppinc7_$100,000 to $149,999                                                    0
# ppinc7_$150,000 or more                                                        0
# ppinc7_$25,000 to $49,999                                                      0
# ppinc7_$50,000 to $74,999                                                      0
# ppinc7_$75,000 to $99,999                                                      0
# ppinc7_Less than $10,000                                                       0
# ppemploy_Not working                                                           0
# ppemploy_Working full-time                                                     0
# ppemploy_Working part-time                                                     0
# ppmarit5_Divorced                                                              0
# ppmarit5_Never married                                                         0
# ppmarit5_Now married                                                           0
# ppmarit5_Separated                                                             0
# ppmarit5_Widowed                                                               0
# ppagecat_18-24                                                                 0
# ppagecat_25-34                                                                 0
# ppagecat_35-44                                                                 0
# ppagecat_45-54                                                                 0
# ppagecat_55-64                                                                 0
# ppagecat_65-74                                                                 0
# ppagecat_75+                                                                   0
# ppfs1482_Don’t know                                                            0
# ppfs1482_Excellent                                                             0
# ppfs1482_Fair                                                                  0
# ppfs1482_Good                                                                  0
# ppfs1482_Poor                                                                  0
# ppfs1482_Very poor                                                             0
# B3_About the same                                                              0
# B3_Much better off                                                             0
# B3_Much worse off                                                              0
# B3_Somewhat better off                                                         0
# B3_Somewhat worse off                                                          0
# A6_Don’t know                                                                  0
# A6_Not confident                                                               0
# A6_Somewhat confident                                                          0
# A6_Very confident                                                              0
# C4A_Most or all of the time                                                    0
# C4A_Never carried an unpaid balance (always pay in full)                       0
# C4A_Once                                                                       0
# C4A_Some of the time                                                           0
# L0C_1                                                                          0
# L0C_2                                                                          0
# L0C_3                                                                          0
# L0C_4                                                                          0
# L0C_5 or more                                                                  0
# dtype: int64

# %%
data2024_cleaned = data2024_cleaned.dropna()

# %% [markdown]
# comment: note this is a small sample with 455 records after removing na rows

# %% [markdown]
# ### Feature selection

# %%
# independent variables
X = data2024_cleaned.drop(columns=['BNPL3','weight'])
# target variable
y = data2024_cleaned['BNPL3']

# weights
weights = data2024_cleaned['weight']

# %%
from imblearn.pipeline import Pipeline

BNPL3_2024_svc_model = LinearSVC(max_iter=2000)

rfecv = RFECV(
    estimator=BNPL3_2024_svc_model,
    step=1,
    cv=StratifiedKFold(5, shuffle=True, random_state=42),
    scoring="f1"
)

# pipeline: resampling happens BEFORE RFECV in each fold
pipeline = Pipeline(steps=[
    ("resample", RandomOverSampler(random_state=42)),
    ("feature_selection", rfecv)
])

# Fit pipeline
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('resample', RandomOverSampler(random_state=42)),
#                 ('feature_selection',
#                  RFECV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                        estimator=LinearSVC(max_iter=2000), scoring='f1'))])

# %%
# get selected features
rfecv = pipeline.named_steps["feature_selection"]
mask = rfecv.support_
selected_features_BNPL3_2024 = X.columns[mask]
print(selected_features_BNPL3_2024)
# Out:
# Index(['EF3_c', 'I41_c', 'A1_a', 'A1_c', 'EF5C', 'I20_Less than your income',
#        'I20_More than your income', 'ppfs0596_$250,000 - $499,999',
#        'ppfs0596_$50,000 - $99,999', 'ppfs0596_$500,000 - $999,999',
#        'ppethm_Hispanic', 'ppethm_Other, Non-Hispanic',
#        'ppethm_White, Non-Hispanic', 'ppinc7_$150,000 or more',
#        'ppinc7_$75,000 to $99,999', 'ppinc7_Less than $10,000',
#        'ppemploy_Working full-time', 'ppemploy_Working part-time',
#        'ppmarit5_Never married', 'ppmarit5_Separated', 'ppagecat_35-44',
#        'ppagecat_65-74', 'ppfs1482_Don’t know', 'ppfs1482_Good',
#        'ppfs1482_Poor', 'B3_Much worse off', 'B3_Somewhat better off',
#        'A6_Don’t know', 'C4A_Most or all of the time', 'C4A_Once', 'L0C_3'],
#       dtype='str')

# %% [markdown]
# ### SVC Model

# %%
# ---------------------------
# 1. Prepare data
# ---------------------------
X_aug = X.copy()
X_aug = X_aug[selected_features_BNPL3_2024]
X_aug["weight"] = weights

# ---------------------------
# 2. Train-test split
# ---------------------------
X_train_aug, X_test_aug, y_train, y_test = train_test_split(
    X_aug, y, test_size=0.2, random_state=42, stratify=y
)

# ---------------------------
# 3. Cross-validation
# ---------------------------
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

auc_scores = []
y_true_all = []
y_pred_all = []
weights_all = []
f1_scores = []

for train_idx, val_idx in skf.split(X_train_aug, y_train):

    X_tr = X_train_aug.iloc[train_idx].copy()
    X_val = X_train_aug.iloc[val_idx].copy()

    y_tr = y_train.iloc[train_idx]
    y_val = y_train.iloc[val_idx]

    # Resample ONLY training fold
    ros = RandomOverSampler(random_state=42)
    X_tr_res, y_tr_res = ros.fit_resample(X_tr, y_tr)

    # Extract weights
    w_tr_res = X_tr_res["weight"].values
    X_tr_res = X_tr_res.drop(columns=["weight"])

    w_val = X_val["weight"].values
    X_val = X_val.drop(columns=["weight"])

    # Train model
    model = LinearSVC(
        C=0.1,
        penalty='l1',
        dual=False,
        max_iter=5000
    )

    model.fit(X_tr_res, y_tr_res, sample_weight=w_tr_res)
    y_pred = model.predict(X_val)

    # ---------------------------
    # 4. Evaluation
    # ---------------------------

    # AUC
    y_scores = model.decision_function(X_val)
    auc = roc_auc_score(y_val, y_pred)
    auc_scores.append(auc)

    # F1
    f1 = f1_score(y_val, y_pred)
    f1_scores.append(f1)

    # Confusion matrix metrics
    y_true_all.extend(y_val)
    y_pred_all.extend(y_pred)
    weights_all.extend(w_val)

# %% [markdown]
# Evaluation results

# %%
# ---------------------------
# 5. Model results
# ---------------------------

print("CV AUC:", np.mean(auc_scores))
print("F1 Score:", np.mean(f1_scores))

cm = confusion_matrix(
    y_true_all,
    y_pred_all,
    sample_weight=weights_all,
    normalize='true'
)

print("Confusion Matrix:", cm)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=np.unique(y_train),
    yticklabels=np.unique(y_train)
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - BNPL3 2024 SVC Model")
plt.show()
# Out:
# CV AUC: 0.7439550072568941
# F1 Score: 0.6162122027105416
# Confusion Matrix: [[0.74539089 0.25460911]
#  [0.25450439 0.74549561]]
